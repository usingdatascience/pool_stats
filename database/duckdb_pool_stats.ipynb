# %%
import duckdb

# %%
duckdb.sql("SELECT 42").show()
# Out:
# ┌───────┐
# │  42   │
# │ int32 │
# ├───────┤
# │    42 │
# └───────┘

# %%
duckdb.read_csv("fact_player_stats.csv") # read a CSV file into a Relation
# Out:
# ┌────────┬─────────────┬───────────┬───────────┬───────────────┬─────────┬───────────┬────────────┐
# │ fps_id │ opponent_id │ games_won │ season_id │ match_date_id │   h_a   │ player_id │ games_lost │
# │ int64  │    int64    │   int64   │   int64   │     int64     │ varchar │   int64   │   int64    │
# ├────────┼─────────────┼───────────┼───────────┼───────────────┼─────────┼───────────┼────────────┤
# │      1 │           5 │         2 │         1 │          2172 │ H       │         4 │          0 │
# │      2 │           4 │         1 │         1 │          2179 │ A       │         4 │          0 │
# │      3 │           9 │         0 │         1 │          2214 │ A       │         4 │          1 │
# │      4 │           2 │         0 │         1 │          2221 │ A       │         4 │          1 │
# │      5 │           8 │         1 │         1 │          2228 │ H       │         4 │          1 │
# │      6 │           3 │         2 │         1 │          2235 │ A       │         4 │          0 │
# │      7 │           1 │         0 │         1 │          2242 │ A       │         4 │          1 │
# │      8 │           5 │         1 │         1 │          2249 │ A       │         4 │          0 │
# │      9 │           4 │         2 │         1 │          2256 │ H       │         4 │          0 │
# │     10 │           6 │         0 │         1 │          2277 │ A       │         4 │          1 │
# │      · │           · │         · │         · │            ·  │ ·       │         · │          · │
# │      · │           · │         · │         · │            ·  │ ·       │         · │          · │
# │      · │           · │         · │         · │            ·  │ ·       │         · │          · │
# │    610 │          14 │         1 │         5 │          1843 │ A       │         5 │          0 │
# │    611 │          15 │         0 │         5 │          1850 │ H       │         5 │          1 │
# │    612 │           3 │         0 │         5 │          1864 │ H       │         5 │          1 │
# │    613 │           1 │         0 │         5 │          1871 │ A       │         5 │          1 │
# │    614 │           4 │         0 │         5 │          1885 │ A       │         5 │          1 │
# │    615 │           2 │         0 │         5 │          1892 │ H       │         5 │          1 │
# │    616 │          29 │         0 │         5 │          1899 │ A       │         5 │          1 │
# │    617 │          15 │         1 │         5 │          1913 │ A       │         5 │          1 │
# │    618 │          29 │         1 │         5 │          1836 │ H       │         9 │          0 │
# │    619 │          15 │         1 │         5 │          1850 │ H       │         9 │          0 │
# ├────────┴─────────────┴───────────┴───────────┴───────────────┴─────────┴───────────┴────────────┤
# │ 619 rows (20 shown)                                                                   8 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# create a connection to a file called 'file.db'
con = duckdb.connect("pool_stats.db")

# %%
opp_history = con.sql(
    """
select t.team_name as teamname, h_a as home_away, count(distinct match_date_id) as total_played, 
        sum(games_won) as games_won, sum(games_lost) as games_lost 
from fact_player_stats f, 
     dim_season s, 
     dim_team t 
where f.season_id = s.season_id 
and t.team_id = f.opponent_id 
group by t.team_name, h_a 
order by games_won desc, team_name
""").df()

# %%
opp_history.head(20)
# Out:
#                     teamname home_away  total_played  games_won  games_lost
# 0                  Garibaldi         A             7       32.0        20.0
# 1                  Garibaldi         H             5       22.0        20.0
# 2   The Crown (Hardingstone)         A             5       19.0        21.0
# 3            Road To Morroco         H             4       18.0        10.0
# 4                  Squirrels         A             4       18.0        13.0
# 5                 Cock Inn A         H             6       17.0        17.0
# 6                 Barratts A         H             4       16.0        14.0
# 7                  Coopers Q         A             5       16.0        16.0
# 8                  Coopers Q         H             3       16.0        14.0
# 9                 Cock Inn A         A             5       15.0        13.0
# 10              King Billy A         H             2       15.0         5.0
# 11                Forresters         H             3       14.0        16.0
# 12                 Squirrels         H             3       14.0        16.0
# 13              Monks Park B         H             3       13.0         7.0
# 14                    Sevens         A             2       13.0         7.0
# 15                Barratts A         A             4       12.0        20.0
# 16              King Billy A         A             2       12.0         8.0
# 17                    Sevens         H             2       12.0         8.0
# 18  The Crown (Hardingstone)         H             3       12.0        16.0
# 19            Gardeners Arms         H             2       11.0         1.0

# %%
players_streaks = con.sql(
    """
select p.player_name, h_a, games_won, games_lost, d.CalendarDateInterval
from fact_player_stats f, dim_player p, DateDimension d
where p.player_id = f.player_id
and f.match_date_id = d.date_id
order by p.player_name, d.CalendarDateInterval desc
""").df()

# %%
players_streaks.head(10)
# Out:
#      player_name h_a  games_won  games_lost  \
# 0  Colin Chapman   H          0           1
# 1  Colin Chapman   H          1           0
# 2  Colin Chapman   H          1           0
# 3  Colin Chapman   A          0           1
# 4  Colin Chapman   H          0           1
# 5  Colin Chapman   A          1           0
# 6  Colin Chapman   A          1           0
# 7  Colin Chapman   A          1           0
# 8  Colin Chapman   H          0           1
# 9  Colin Chapman   A          1           0
#
#                                 CalendarDateInterval
# 0  [50, 48, 50, 51, 45, 48, 52, 45, 49, 55, 32, 4...
# 1  [50, 48, 50, 51, 45, 48, 52, 45, 49, 48, 32, 4...
# 2  [50, 48, 50, 51, 45, 48, 52, 45, 48, 51, 32, 4...
# 3  [50, 48, 50, 51, 45, 48, 51, 45, 50, 55, 32, 4...
# 4  [50, 48, 50, 51, 45, 48, 51, 45, 50, 48, 32, 4...
# 5  [50, 48, 50, 51, 45, 48, 51, 45, 49, 51, 32, 4...
# 6  [50, 48, 50, 51, 45, 48, 51, 45, 48, 54, 32, 4...
# 7  [50, 48, 50, 51, 45, 48, 50, 45, 50, 55, 32, 4...
# 8  [50, 48, 50, 51, 45, 48, 50, 45, 50, 48, 32, 4...
# 9  [50, 48, 50, 51, 45, 48, 50, 45, 49, 51, 32, 4...

# %%
opps_all_hist = con.sql(
    """
select  t.team_name, count(distinct match_date_id) as "total_played", 
        sum(games_won) as "games_won", sum(games_lost) as "games_lost"
from fact_player_stats f,
     dim_season s,
     dim_team t
where f.season_id = s.season_id
and t.team_id = f.opponent_id
group by t.team_name
order by games_won desc, team_name
""").df()

# %%
opps_all_hist.head(20)
# Out:
#                    team_name  total_played  games_won  games_lost
# 0                  Garibaldi            12       54.0        40.0
# 1                 Cock Inn A            10       32.0        30.0
# 2                  Coopers Q             8       32.0        30.0
# 3                  Squirrels             6       32.0        29.0
# 4   The Crown (Hardingstone)             8       31.0        37.0
# 5                 Barratts A             8       28.0        34.0
# 6               King Billy A             4       27.0        13.0
# 7            Road To Morroco             8       27.0        32.0
# 8                     Sevens             4       25.0        15.0
# 9                 Forresters             7       24.0        36.0
# 10              Monks Park B             6       22.0        18.0
# 11             Swan & Helmet             5       22.0        18.0
# 12                  The Bear             2       15.0         5.0
# 13            Gardeners Arms             3       14.0         6.0
# 14                     Vocal             2       13.0         7.0
# 15                Barratts B             4       12.0        24.0
# 16              Edge of Town             2       12.0         8.0
# 17              King Billy W             3       12.0         6.0
# 18              ClubSports A             3       11.0         9.0
# 19                 Coopers Y             5       11.0         9.0

# %%
players_rec_teams = con.sql(
    """
select  p.player_name, 
        team_name, 
        sum(games_won) won, 
        sum(games_lost) lost,
        count(distinct match_date_id) matches
 from fact_player_stats f,
      dim_team t,
      dim_player p
 where t.team_id = f.opponent_id
 and p.player_id = f.player_id
 group by p.player_name, team_name
 order by p.player_name, team_name
""").df()

# %%
players_rec_teams.head(20)
# Out:
#       player_name        team_name  won  lost  matches
# 0   Colin Chapman       Barratts A  2.0   2.0        4
# 1   Colin Chapman       Barratts B  0.0   3.0        2
# 2   Colin Chapman     ClubSports A  2.0   1.0        2
# 3   Colin Chapman     ClubSports C  1.0   0.0        1
# 4   Colin Chapman       Cock Inn A  1.0   3.0        4
# 5   Colin Chapman        Coopers B  1.0   2.0        2
# 6   Colin Chapman        Coopers Q  5.0   5.0        6
# 7   Colin Chapman        Coopers Y  3.0   1.0        2
# 8   Colin Chapman     Edge of Town  2.0   2.0        2
# 9   Colin Chapman       Forresters  2.0   4.0        6
# 10  Colin Chapman   Gardeners Arms  2.0   1.0        2
# 11  Colin Chapman        Garibaldi  6.0   3.0        7
# 12  Colin Chapman     King Billy A  2.0   3.0        3
# 13  Colin Chapman     King Billy W  2.0   0.0        2
# 14  Colin Chapman        Mailcoach  0.0   1.0        1
# 15  Colin Chapman     Monks Park B  2.0   2.0        4
# 16  Colin Chapman  Road To Morroco  2.0   2.0        4
# 17  Colin Chapman           Sevens  4.0   2.0        4
# 18  Colin Chapman     Spread Eagle  0.0   3.0        2
# 19  Colin Chapman        Squirrels  5.0   4.0        6

# %%
players_vs_opps = con.sql(
    """
select  p.player_name, team_name, count(distinct match_date_id) as "total_played",
       sum(games_won) as "games_won", sum(games_lost) as "games_lost"
from fact_player_stats f,
     dim_team t,
     dim_player p
where t.team_id = f.opponent_id
and p.player_id = f.player_id
/* and p.player_name = 'Liam Chapman' */
group by p.player_name, team_name
order by p.player_name, team_name
""").df()

# %%
players_vs_opps
# Out:
#        player_name                 team_name  total_played  games_won  \
# 0    Colin Chapman                Barratts A             4        2.0
# 1    Colin Chapman                Barratts B             2        0.0
# 2    Colin Chapman              ClubSports A             2        2.0
# 3    Colin Chapman              ClubSports C             1        1.0
# 4    Colin Chapman                Cock Inn A             4        1.0
# ..             ...                       ...           ...        ...
# 209  Steve Dunkley             Swan & Helmet             2        1.0
# 210  Steve Dunkley                  The Bear             2        1.0
# 211  Steve Dunkley  The Crown (Hardingstone)             1        0.0
# 212  Steve Dunkley                  Turnpike             1        0.0
# 213  Steve Dunkley                     Vocal             1        2.0
#
#      games_lost
# 0           2.0
# 1           3.0
# 2           1.0
# 3           0.0
# 4           3.0
# ..          ...
# 209         1.0
# 210         1.0
# 211         1.0
# 212         2.0
# 213         0.0
#
# [214 rows x 5 columns]

# %%
seasons = con.sql(
    """
select  *  from dim_season
""").df()

# %%
seasons
# Out:
#    season_id                                        season_name
# 0          1  [68, 101, 99, 32, 50, 48, 50, 50, 32, 45, 32, ...
# 1          2  [74, 117, 110, 32, 50, 48, 50, 50, 32, 45, 32,...
# 2          3  [83, 101, 112, 32, 50, 48, 49, 56, 32, 45, 32,...
# 3          4  [74, 117, 110, 32, 32, 50, 48, 49, 57, 32, 45,...
# 4          5  [78, 111, 118, 32, 50, 48, 50, 49, 32, 45, 32,...
